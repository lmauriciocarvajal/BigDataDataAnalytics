# %% [markdown]
# # 1 Import and prepare DATA

# %% [markdown]
# ## 1.1  Libraries

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
from matplotlib import pylab
from pylab import *

# Set default matplot figure size
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# ## 1.2 Import Data

# %%
#Import Data
credit = pd.read_csv('Data/default_of_creditcardclients.csv', header =1)
credit = pd.read_csv('Data/default_of_creditcardclients.csv', header =1)

# %% [markdown]
# ## 1.3 Review Data

# %%
#quick sample the dataframe 
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#In R you used the summary() function to easily do this. In Pandas we can use the describe() 
# function to do the same thing as follows:
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
#to check the data types of each variable 
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %% [markdown]
# ## 1.4 Prepare Data

# %% [markdown]
# ### 1.4.1 Misssing Value

# %%
#the total number of missing values in the DataFrame
print(credit.isnull().values.sum())

#credict.dropna()
# Out:
# 0

# %% [markdown]
# ### 1.4.2 Data transformation
# Converting the data from numerical to chategorical value

# %%
#converting Data from int to chategorical value
#(1 = male; 2 = female)
credit['SEX']=credit['SEX'].astype('object')

#(1 = graduate school; 2 = university; 3 = high school; 0, 4, 5, 6 = others)
credit['EDUCATION']=credit['EDUCATION'].astype('object')

# (1 = married; 2 = single; 3 = divorce; 0=others)
credit['MARRIAGE']=credit['MARRIAGE'].astype('object')

#X6 - X11: History of past payment. We tracked the past monthly payment records (from
#April to September, 2005) as follows: X6 = the repayment status in September, 2005; X7
#= the repayment status in August, 2005; . . .;X11 = the repayment status in April, 2005.
#The measurement scale for the repayment status is:
#-2: No consumption; -1: Paid in full; 0: The use of revolving credit; 1 = payment delay
#for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight
#months; 9 = payment delay for nine months and above.
credit['PAY_0']=credit['PAY_0'].astype('object')
credit['PAY_2']=credit['PAY_2'].astype('object')
credit['PAY_3']=credit['PAY_3'].astype('object')
credit['PAY_4']=credit['PAY_4'].astype('object')
credit['PAY_5']=credit['PAY_5'].astype('object')
credit['PAY_6']=credit['PAY_6'].astype('object')

#client's behavior; Y=0 then not default, Y=1 then default
#credit['default payment next month']=credit['default payment next month'].astype('object')

# %%
#Saved
credit.to_csv(r'Data/default_of_creditcardclientsPreproced.csv', index = False)

# %% [markdown]
# # 2 Perform Exploratory Analysis (EDA)
# (EDA) is an integral aspect of any greater data analysis, data science, or machine learning project. Understanding data before working with it isn't just a pretty good idea, it is a priority if you plan on accomplishing anything of consequence."
#
# EDA usually involves at least some, if not all, of the following:
#
#     Visualization and Statistics about each variable - you've already done part of this with describe().
#
#     Scatter plots comparing the relationships between any two variables
#
#     If needed, visualizing the relationship between many (more than 2) variables
#
#     Checking for collinearity or performing dimensionality reduction

# %% [markdown]
# ## 2.1 Visualizing the data

# %% [markdown]
# ### 2.1.1 Histograms
# Histograms are very useful for understanding how the data is distributed in any given single (univariate) variab

# %%
#Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Next, lets make sure we know the column names in our dataframe so we can begin to build plots for each, where needed
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
#Note: You can specify the number of bins in your histograms by adding bins='X' as follows:
#TIP:
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %% [markdown]
# ### 2.1.2  Line Plots
# Line plots are often used in EDA to illustrate the range and mode of any given numerical variable. This can be very important for things like preventing bias and model overfit and even identifying collinearity.
#
# Creating line plots is very easy in matplotlib and can be done for a single variable or for multiple variables at once (multivariate)

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %% [markdown]
# ### 2.1.3 Scatter Plots
# Scatter plots are very useful for comparing two features (bivariate and multiple features (multivariate) to each other. This is very useful for understanding any possible relationships between the data, but as you are aware, does not always point to any causal relationship.

# %%
#to create a comparison of any two features we must first set the two features equal to variables
x = credit['PAY_0']
y = credit['PAY_2']
#matplotlib
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### 2.1.3  Box Plots
# Box plots, sometimes called Box and Whisker Plots, are very useful for quickly visualizing where the bulk of the data is in any given feature ad are also very useful for identifying feature with outliers or extreme variances in the observations. As you already know understanding what features might contain outliers is very important in Data Science and very important for Machine Learning. Lets look at the different components that make up a good box plot.

# %%
#look at our column names
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %% [markdown]
# ## 2.2 Correlation
#  Whether addressing collinearity or checking for relationships between features for selection or engineering, calculating correlation is a vital part of all Data Science projects and it is easy to do using pandas or even numpy.

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       AGE  BILL_AMT1  \
# ID                          1.000000   0.026179  0.018678   0.019389
# LIMIT_BAL                   0.026179   1.000000  0.144713   0.285430
# AGE                         0.018678   0.144713  1.000000   0.056239
# BILL_AMT1                   0.019389   0.285430  0.056239   1.000000
# BILL_AMT2                   0.017982   0.278314  0.054283   0.951484
# BILL_AMT3                   0.024354   0.283236  0.053710   0.892279
# BILL_AMT4                   0.040351   0.293988  0.051353   0.860272
# BILL_AMT5                   0.016705   0.295562  0.049345   0.829779
# BILL_AMT6                   0.016730   0.290389  0.047613   0.802650
# PAY_AMT1                    0.009742   0.195236  0.026147   0.140277
# PAY_AMT2                    0.008406   0.178408  0.021785   0.099355
# PAY_AMT3                    0.039151   0.210167  0.029247   0.156887
# PAY_AMT4                    0.007793   0.203242  0.021379   0.158303
# ...

# %% [markdown]
# ## 2.3 Covariance
# Covariance is often used to gauge the linear degree of change between two variables. Simply put, you can use covariance to measure how changes in one variable are associated with changes in a second variable. This will be very important when studying the impact various features might have on default rates so make sure you understand it fully.

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL            AGE  \
# ID                          7.500250e+07  2.941664e+07    1491.057019
# LIMIT_BAL                   2.941664e+07  1.683446e+10  173076.722569
# AGE                         1.491057e+03  1.730767e+05      84.969755
# BILL_AMT1                   1.236447e+07  2.727020e+09   38172.933546
# BILL_AMT2                   1.108392e+07  2.570130e+09   35613.657962
# BILL_AMT3                   1.462688e+07  2.548533e+09   34334.251320
# BILL_AMT4                   2.248126e+07  2.453926e+09   30453.108180
# BILL_AMT5                   8.795803e+06  2.331481e+09   27654.067800
# BILL_AMT6                   8.628506e+06  2.243837e+09   26137.648547
# PAY_AMT1                    1.397501e+06  4.195711e+08    3992.041735
# PAY_AMT2                    1.677383e+06  5.333504e+08    4626.861549
# PAY_AMT3                    5.969803e+06  4.801180e+08    4746.824393
# ...

# %% [markdown]
# # 3 EDA
# https://github.com/TarekDib03/titanic-EDA

# %% [markdown]
# ## 3.1 Analysis

# %%
# Check the first 5 rows of the data frame
credit.head()
# Out:
#    ID  LIMIT_BAL SEX EDUCATION MARRIAGE  AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# 0   1      20000   2         2        1   24     2     2    -1    -1  ...
# 1   2     120000   2         2        2   26    -1     2     0     0  ...
# 2   3      90000   2         2        2   34     0     0     0     0  ...
# 3   4      50000   2         2        1   37     0     0     0     0  ...
# 4   5      50000   1         2        1   57    -1     0    -1     0  ...
#
#   BILL_AMT4 BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0         0         0          0         0       689         0         0
# 1      3272      3455       3261         0      1000      1000      1000
# 2     14331     14948      15549      1518      1500      1000      1000
# 3     28314     28959      29547      2000      2019      1200      1100
# 4     20940     19146      19131      2000     36681     10000      9000
#
#    PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# Column names
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# Information about the data set
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null object
# EDUCATION                     30000 non-null object
# MARRIAGE                      30000 non-null object
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null object
# PAY_2                         30000 non-null object
# PAY_3                         30000 non-null object
# PAY_4                         30000 non-null object
# PAY_5                         30000 non-null object
# PAY_6                         30000 non-null object
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
#Changing the names
credit.loc[credit['SEX'] == 1 , 'SEX'] = 'Male'
credit.loc[credit['SEX'] == 2 , 'SEX'] = 'Female'

credit.loc[credit['EDUCATION'] == 0 , 'EDUCATION'] = 'Other_0'
credit.loc[credit['EDUCATION'] == 1 , 'EDUCATION'] = 'Graduate_School'
credit.loc[credit['EDUCATION'] == 2 , 'EDUCATION'] = 'University'
credit.loc[credit['EDUCATION'] == 3 , 'EDUCATION'] = 'High_School'
credit.loc[credit['EDUCATION'] == 4 , 'EDUCATION'] = 'Other_4'
credit.loc[credit['EDUCATION'] == 5 , 'EDUCATION'] = 'Other_5'
credit.loc[credit['EDUCATION'] == 6 , 'EDUCATION'] = 'Other_6'

credit.loc[credit['MARRIAGE'] == 0 , 'MARRIAGE'] = 'Others'
credit.loc[credit['MARRIAGE'] == 1 , 'MARRIAGE'] = 'Married'
credit.loc[credit['MARRIAGE'] == 2 , 'MARRIAGE'] = 'Single'
credit.loc[credit['MARRIAGE'] == 3 , 'MARRIAGE'] = 'Divorce'

#credit.loc[credit['default payment next month'] == 0 , 'default payment next month'] = 'Not_Default'
#credit.loc[credit['default payment next month'] == 1 , 'default payment next month'] = 'Default'

# %%
# Number of person in each class
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# Graduate_School    10585
# High_School         4917
# Other_0               14
# Other_4              123
# Other_5              280
# Other_6               51
# University         14030
# Name: EDUCATION, dtype: int64

# %%
# Instead of a group by, use seaborn to plot the count of passengers in each class
fg = sns.factorplot('EDUCATION', data=credit, kind='count', aspect=1.5)
#fg.set_xlabels('Class')

# %% [markdown]
# Conclusion: Most of the people has education, in which is easy to see that most of the people are with university degree.

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# Female    18112
# Male      11888
# Name: SEX, dtype: int64

# %%
# Instead of a group by, use seaborn to plot the number of males and females
sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)

# %% [markdown]
# Conclusion: Most of the people are femeles

# %%
# Number of men and women in each of the education
credit.groupby(['SEX', 'EDUCATION'])['SEX'].count()
# Out:
# SEX     EDUCATION
# Female  Graduate_School    6231
#         High_School        2927
#         Other_0               6
#         Other_4              81
#         Other_5             185
#         Other_6              26
#         University         8656
# Male    Graduate_School    4354
#         High_School        1990
#         Other_0               8
#         Other_4              42
#         Other_5              95
#         Other_6              25
#         University         5374
# Name: SEX, dtype: int64

# %%
# Again use saeborn to group by Sex and Education
g = sns.factorplot('EDUCATION', data=credit, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('EDUCATION')

# %% [markdown]
# Conclusion: More female with education

# %%
# Number of clients that are going to have default pyment next month aach gender gruoped by education.
credit.pivot_table('default payment next month', 'EDUCATION', 'SEX', aggfunc=np.sum, margins=True)
# Out:
# SEX              Female  Male   All
# EDUCATION
# Graduate_School    1130   906  2036
# High_School         692   545  1237
# Other_0               0     0     0
# Other_4               3     4     7
# Other_5              12     6    18
# Other_6               4     4     8
# University         1922  1408  3330
# All                3763  2873  6636

# %%
#Here we are taking only the clients that are not going to default next month payment
not_default = credit[credit['default payment next month']==0]

# %%
# Factor plot of those who survived vs. who didn't
sns.factorplot('default payment next month', data=credit, kind='count')

# %% [markdown]
# Conclusion: Almost 3 times of the person will not fhave default payment next month

# %%
# Total number of clients that are not default
len(not_default)
# Out:
# 23364

# %%
# Number of clients that are NOT going to have default pyment next month aach gender gruoped by education.
not_default.pivot_table('default payment next month', 'EDUCATION', 'SEX', aggfunc=len, margins=True)
# Out:
# SEX              Female  Male    All
# EDUCATION
# Graduate_School    5101  3448   8549
# High_School        2235  1445   3680
# Other_0               6     8     14
# Other_4              78    38    116
# Other_5             173    89    262
# Other_6              22    21     43
# University         6734  3966  10700
# All               14349  9015  23364

# %%
#"Important that aggfunc is len insted of sum that are shown adove"

# %%
#changing the long nanme-->default payment next month
credit = credit.rename(columns={'default payment next month': 'default_payment_next_month'})

# %%
# Passengers who survived and who didn't survive grouped by class and sex
#table = pd.crosstab(index=[credit.default_payment_next_month,credit.EDUCATION], columns=[credit.SEX,credit.Embarked])

# %%
print('Average and median age of passengers are %0.f and %0.f years old, respectively'%(credit.AGE.mean(), 
                                                                          credit.AGE.median()))
# Out:
# Average and median age of passengers are 35 and 34 years old, respectively

# %%
credit.AGE.describe()
# Out:
# count    30000.000000
# mean        35.485500
# std          9.217904
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: AGE, dtype: float64

# %%
# Drop missing values for the records in which age clients is missing
AGE = credit['AGE'].dropna()

# %%
# Distribution of age, with an overlay of a density plot
age_dist = sns.distplot(AGE)
age_dist.set_title("Distribution of Clients' Ages")
# Out:
# Text(0.5, 1.0, "Distribution of Clients' Ages")

# %% [markdown]
# Conclusion: Top clients are youth and youth adults people

# %%
# Another way to plot a histogram of ages is shown below
credit['AGE'].hist(bins=50)

# %%
#Locking the clients by range of age
credit['AGE'].hist(bins=10)

# %%
#https://www.statcan.gc.ca/eng/concepts/definitions/age2 
def age_distribution(passenger):
    AGE, SEX = passenger
    
    if  AGE < 14:
        return 'Children'
    elif  AGE < 24:
        return 'Youth'
    if  AGE < 34:
        return 'Youth Adults'
    if  AGE < 64:
        return 'Adults'
    else:
        return "Seniors"

# %%
credit['person'] = credit[['AGE', 'SEX']].apply(age_distribution, axis=1)

# %%
# Lets have a look at the first 10 rows of the data frame
credit[:10]
# Out:
#    ID  LIMIT_BAL     SEX        EDUCATION MARRIAGE  AGE PAY_0 PAY_2 PAY_3  \
# 0   1      20000  Female       University  Married   24     2     2    -1
# 1   2     120000  Female       University   Single   26    -1     2     0
# 2   3      90000  Female       University   Single   34     0     0     0
# 3   4      50000  Female       University  Married   37     0     0     0
# 4   5      50000    Male       University  Married   57    -1     0    -1
# 5   6      50000    Male  Graduate_School   Single   37     0     0     0
# 6   7     500000    Male  Graduate_School   Single   29     0     0     0
# 7   8     100000  Female       University   Single   23     0    -1    -1
# 8   9     140000  Female      High_School  Married   28     0     0     2
# 9  10      20000    Male      High_School   Single   35    -2    -2    -2
#
#   PAY_4  ... BILL_AMT5 BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0    -1  ...         0         0         0       689         0         0
# ...

# %%
sns.factorplot('MARRIAGE', data=credit, kind='count',  hue='person', aspect=2,
               hue_order=["Youth","Youth Adults", "Adults", "Seniors"])


# Instead of a group by, use seaborn to plot the count of passengers in each class
#fg = sns.factorplot('EDUCATION', data=credit, kind='count', aspect=1.5)
#fg.set_xlabels('Class')

# %% [markdown]
# Conclusion: Most of the Adults are married, and most of the single are youth adutls

# %%
# Do the same as above, but split the passengers into either survived or not
sns.factorplot('MARRIAGE', data=credit, kind='count', hue='person', col='default_payment_next_month', aspect=1.25, size=5,
              hue_order=["Youth","Youth Adults", "Adults", "Seniors"])

# %% [markdown]
# Conclusion: The number of those that have defualt payment next month is very low, but present similar behaviour between the education levels, the behavior is the same between marriage distribution

# %% [markdown]
# ## 3.2  kde plot, Distribution of Clients  Ages

# %% [markdown]
# ### 3.2.1 Grouped by Gender

# %%
fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()

# %% [markdown]
# Conclusion: Distribution are very young people for female and male genders

# %%
fig = sns.FacetGrid(credit, hue='person', aspect=3)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %% [markdown]
# Conclusion: Distribution by range of anges

# %% [markdown]
# ### 3.2.2 Grouped by education

# %%
fig = sns.FacetGrid(credit, hue='EDUCATION', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Education')
fig.add_legend()

# %% [markdown]
# ### 3.2.2 Grouped by marriage

# %%
fig = sns.FacetGrid(credit, hue='MARRIAGE', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by MARRIAGE')
fig.add_legend()

# %%
deck = credit['BILL_AMT6'].dropna()
deck.head()
# Out:
# 0        0
# 1     3261
# 2    15549
# 3    29547
# 4    19131
# Name: BILL_AMT6, dtype: int64

# %%
#from collections import Counter
#Counter(credit['BILL_AMT6'])

# %%
fig = sns.FacetGrid(credit, hue='PAY_6', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Payment delays')
fig.add_legend()

# %% [markdown]
# Conclusion: In this distribution we can see that a there is a tendency of certain group of 30 & 50 years to have payment delay for eight
# month

# %%
# Do the same as above, but split the passengers into either survived or not
sns.factorplot('person', data=credit, kind='count', hue='PAY_6', col='default_payment_next_month', aspect=1.25, size=5,
               order=["Youth","Youth Adults", "Adults", "Seniors"])#, palette='Greens_d')

# %% [markdown]
# Conclusion: the use of revolving credit have higher values

# %%
fig = sns.FacetGrid(credit, hue='person', aspect=4,hue_order=["Youth","Youth Adults", "Adults", "Seniors"])
fig.map(sns.kdeplot, 'LIMIT_BAL', shade=True)
oldest = credit['LIMIT_BAL'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of amount creditl per Person')
fig.add_legend()

# %% [markdown]
# Conclusion: In this gralphic there are somme conclusions:
#
# 1- Youth people tend to have limited credit
#
# 2-Adults and seniors have similar credit distritubion

# %% [markdown]
# ### Discretized Limit

# %%
credit['LIMIT_BAL_Discretized']=pd.cut(credit['LIMIT_BAL'], 4)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0   1      20000  Female  University  Married   24     2     2    -1    -1
# 1   2     120000  Female  University   Single   26    -1     2     0     0
# 2   3      90000  Female  University   Single   34     0     0     0     0
# 3   4      50000  Female  University  Married   37     0     0     0     0
# 4   5      50000    Male  University  Married   57    -1     0    -1     0
#
#    ... BILL_AMT6 PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...         0        0       689         0         0         0         0
# 1  ...      3261        0      1000      1000      1000         0      2000
# 2  ...     15549     1518      1500      1000      1000      1000      5000
# 3  ...     29547     2000      2019      1200      1100      1069      1000
# 4  ...     19131     2000     36681     10000      9000       689       679
#
# ...

# %%
# Do the same as above, but split the passengers into either survived or not
sns.factorplot('default_payment_next_month', data=credit, kind='count', hue='person', col='SEX', aspect=1.25, 
               size=5, hue_order=["Youth","Youth Adults", "Adults", "Seniors"])#, palette='Greens_d')

# %% [markdown]
# Conclusion: Distribution between age are the same

# %%
# Survived vs. class Grouped by gender
sns.factorplot('MARRIAGE','default_payment_next_month', order=['Single','Married','Divorce','Others'],hue='person', data=credit,aspect=2,hue_order=["Youth","Youth Adults", "Adults", "Seniors"])#, order=range(1,4))#, 
               #hue_order = ['child','female','male'])

# %% [markdown]
# Conclusion:Single have a tendency to not have default payment next month

# %%
sns.factorplot('default_payment_next_month', data=credit, hue='LIMIT_BAL_Discretized', kind='count', palette='Pastel2',
              col='person')

# %%
# Linear plot of age vs. survived
sns.lmplot('AGE', 'default_payment_next_month', data=credit)

# %%
# Survived vs. Age grouped by Sex
sns.lmplot('AGE', 'default_payment_next_month', data=credit, hue='SEX')

# %% [markdown]
# Conclusion: There is a low tendency between male to age have a tendency to pay

# %%
# Survived vs. Age gruped by class
sns.lmplot('AGE', 'default_payment_next_month', hue='MARRIAGE', data=credit, palette='winter')#, hue_order=range(1,4))

# %%
# Create a generation bin
generations = [10,20,40,60,80]
sns.lmplot('AGE','default_payment_next_month',hue='MARRIAGE',data=credit,x_bins=generations)#, hue_order=[1,2,3])

# %%
sns.factorplot('MARRIAGE', 'default_payment_next_month', data=credit, palette='winter') #hue='person',

# %%
sns.factorplot('MARRIAGE', 'default_payment_next_month', order=['Single','Married','Divorce','Others'],data=credit, palette='winter', hue='person',
              hue_order=["Youth","Youth Adults", "Adults", "Seniors"])

# %% [markdown]
# Conclusion: The status Others tend to don't have any default payment next month

# %%
# Lets split it by class now!
sns.factorplot('MARRIAGE', 'default_payment_next_month', palette='summer', order=['Single','Married','Divorce','Others'],data=credit, hue='person',
              hue_order=["Youth","Youth Adults", "Adults", "Seniors"],col='SEX')

# %% [markdown]
# Conclusion: Divorce people present a not clear behavior

# %% [markdown]
# # Predictive Modeling

# %%
import sklearn
